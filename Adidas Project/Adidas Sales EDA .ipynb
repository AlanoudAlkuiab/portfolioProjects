# %% [markdown]
#  <h1 style="background-color:red ;color:white;"> <center> Adidas EDA  Project</center></h1>

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# #### Dataset link
# https://www.kaggle.com/datasets/heemalichaudhari/adidas-sales-dataset

# %% [markdown]
# ## ABSTRACT

# %% [markdown]
# The goal of this project is to predict the for Adidas company using the Adidas data that is published in kggle.
# This project explores a publicly available Adidas dataset to gain insights into the company preformance .
# In this project i will try to analyze the dataset by answering some questions through EDA , and building prediction models using machine learning algorthims
#
# The analysis and methodologies provided in this project will give a valuable contributions to understanding the flow of of the comapy's preformace through out time.

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# An Adidas sales dataset is a collection of data that includes information on the sales of Adidas products. This type of dataset may include details such as the number of units sold, the total sales revenue, the location of the sales, the type of product sold, and any other relevant information.
#
# Adidas sales data can be useful for a variety of purposes, such as analyzing sales trends, identifying successful products or marketing campaigns, and developing strategies for future sales. It can also be used to compare Adidas sales to those of competitors, or to analyze the effectiveness of different marketing or sales channels.
#
# There are a variety of sources that could potentially provide an Adidas sales dataset, including Adidas itself, market research firms, government agencies, or other organizations that track sales data. The specific data points included in an Adidas sales dataset may vary depending on the source and the purpose for which it is being used.

# %% [markdown]
# ## DATA EXPLORATION AND DESCRIPTION

# %% [markdown]
# this dataaset contains over 9648 rows and 14 columns .
#
#
#
#
#
# <table >
#   <tr>
#     <th>Attribute</th>
#     <th>Description</th>
#
#   </tr>
#
#   <tr>
#     <td>Retailer</td>
#     <td style="text-align:center">Name of  the retailer</td>
#
#   </tr>
#
#   <tr>
#     <td>Retailer ID</td>
#     <td>Unique ID for each retailer</td>
#
#   </tr>
#
#   <tr>
#     <td>Invoice Date</td>
#     <td>The invoice of the purchased products </td>
#
#   </tr>
#
#   <tr>
#     <td>Region</td>
#     <td>Region </td>
#
#   </tr>
#
#   <tr>
#     <td>State</td>
#     <td>State</td>
#
#   </tr>
#
#   <tr>
#     <td>City</td>
#     <td>City</td>
#
#   </tr>
#
#   <tr>
#     <td>Product	Price per Unit</td>
#     <td>Price for each product</td>
#
#   </tr>
#
#   <tr>
#     <td>Units Sold</td>
#     <td>How many units are sold in one purchase</td>
#
#   </tr>
#
#   <tr>
#     <td>Total Sales</td>
#     <td>the total sales of the product purchase in the transaction</td>
#
#   </tr>
#
#   <tr>
#     <td>Operating Profit</td>
#     <td>Measure of a company's profitability before taking into account interest, taxes, depreciation, and amortization</td>
#
#   </tr>
#
#   <tr>
#     <td>Operating Margin</td>
#     <td> Profitability ratio that measures how much profit a company makes after paying for variable costs of production</td>
#
#   </tr>
#
#   <tr>
#     <td>Sales Method</td>
#     <td>Diffrent ways of purchase</td>
#
#   </tr>
#
# </table>

# %% [markdown]
# ## questions
#
# * which retailer that generate the high sales for Adidas ?
# * which product generae the the highest profit for the Adidas (compare to the number of the unit sold)
# * profatible retailer in each region (pivot table)
#
#
# * what is the profit of each month
# * what is the common sales method that the users use to purchase Adidas (and the profit of each method) ?
#
# * the relationship between the price per unit and the units sold ? dose the lower price means that units sold are hghier
# * wihch region generate higher profit (percentage of sales in eah region)
# * which city the generate hgihest sales
# * slaes trend compar to the date
# * for ex in the weekend the sals of adidas increase that means that the intrudcing new product needs to be in that specific date
#
# * best sales year and month
# * what is the avg price for each product ? comspre it with the highest sales of each product ( like mybe the avg price of mens shoose is hgiher and the hihgest profiatable prooduct is also men shooes

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df=pd.read_excel("Adidas US Sales Datasets.xlsx")

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %%
#making the row index 3 as columns
#columns by thre index of the row
df.columns=df.iloc[3]

# %%
#drop the first 3 rows 
df = df.drop(index=[0, 1,2,3])

# %%
df=df.iloc[:,1:]

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
# 3     Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
# 3      City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
# 3 Operating Profit Operating Margin Sales Method
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
# change the dtypes of sum columns
df[['Price per Unit','Total Sales','Operating Profit','Operating Margin']] = df[['Price per Unit','Total Sales','Operating Profit','Operating Margin']].astype('float')
df['Units Sold'] = df['Units Sold'].astype('int')
#date to datetime
df['Invoice Date']=pd.to_datetime(df['Invoice Date'])

# %%
df.describe()
# Out:
# 3      Price per Unit   Units Sold    Total Sales  Operating Profit  \
# count     9648.000000  9648.000000    9648.000000       9648.000000
# mean        45.216625   256.930037   93273.437500      34425.244761
# std         14.705397   214.252030  141916.016727      54193.113713
# min          7.000000     0.000000       0.000000          0.000000
# 25%         35.000000   106.000000    4254.500000       1921.752500
# 50%         45.000000   176.000000    9576.000000       4371.420000
# 75%         55.000000   350.000000  150000.000000      52062.500000
# max        110.000000  1275.000000  825000.000000     390000.000000
#
# 3      Operating Margin
# count       9648.000000
# mean           0.422991
# std            0.097197
# min            0.100000
# 25%            0.350000
# 50%            0.410000
# 75%            0.490000
# max            0.800000

# %% [markdown]
# # data preproccing

# %%
df.isna().sum()
# Out:
# 3
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#extracting the month and the day and the year in a new columns
df['Year']=df['Invoice Date'].dt.year
df['Month']=df['Invoice Date'].dt.month
df['Day']=df['Invoice Date'].dt.day

# %%
#checking for the number of Regions in the data
df['Region'].value_counts()
# Out:
# West         2448
# Northeast    2376
# Midwest      1872
# South        1728
# Southeast    1224
# Name: Region, dtype: int64

# %%
#checking for any splling error in the Region columns
df['City'].unique()
# Out:
# array(['New York', 'Houston', 'San Francisco', 'Los Angeles', 'Chicago',
#        'Dallas', 'Philadelphia', 'Las Vegas', 'Denver', 'Seattle',
#        'Miami', 'Minneapolis', 'Billings', 'Knoxville', 'Omaha',
#        'Birmingham', 'Portland', 'Anchorage', 'Honolulu', 'Orlando',
#        'Albany', 'Cheyenne', 'Richmond', 'Detroit', 'St. Louis',
#        'Salt Lake City', 'New Orleans', 'Boise', 'Phoenix', 'Albuquerque',
#        'Atlanta', 'Charleston', 'Charlotte', 'Columbus', 'Louisville',
#        'Jackson', 'Little Rock', 'Oklahoma City', 'Wichita',
#        'Sioux Falls', 'Fargo', 'Des Moines', 'Milwaukee', 'Indianapolis',
#        'Baltimore', 'Wilmington', 'Newark', 'Hartford', 'Providence',
#        'Boston', 'Burlington', 'Manchester'], dtype=object)

# %% [markdown]
# # EDA Exploratory Data Analysis

# %% [markdown]
# ### Question 1:\ which retailer that generate the high sales for Adidas ?

# %%
df
# Out:
# 3        Retailer Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker     1185732   2020-01-01  Northeast       New York
# 1     Foot Locker     1185732   2020-01-02  Northeast       New York
# 2     Foot Locker     1185732   2020-01-03  Northeast       New York
# 3     Foot Locker     1185732   2020-01-04  Northeast       New York
# 4     Foot Locker     1185732   2020-01-05  Northeast       New York
# ...           ...         ...          ...        ...            ...
# 9643  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
#
# 3           City                    Product  Price per Unit  Units Sold  \
# ...

# %%
R_TotalSales=df.groupby(['Retailer'])['Total Sales'].sum().sort_values(ascending=False).to_frame()

# %%
# Create a bar plot
sns.barplot(x=R_TotalSales.index, y=R_TotalSales['Total Sales'].values, data=R_TotalSales)

# Customize the plot
sns.set_style('darkgrid')
sns.set_palette('bright')

# Add a title and labels
plt.title('Total Sales Of Adidas By Retailer ')
plt.xlabel('Retailers')
plt.ylabel('Total Sales in millions')

# Customize the appearance of the bars
plt.bar_width = 0.4
plt.bar_edgecolor='white'


# Show the plot
plt.show()

# %%
R_TotalSales.plot(kind='pie',subplots=True,figsize=(12,7),
title='Total sales per Retailer',autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:ylabel='Total Sales'>], dtype=object)

# %% [markdown]
# ## price disturibution of adiass

# %%
df['Price per Unit'].plot(kind='hist',bins=25,figsize=(12,7),title='Products price distribution')
# Out:
# <AxesSubplot:title={'center':'Products price distribution'}, ylabel='Frequency'>

# %%
df['Price per Unit'].mean()
# Out:
# 45.21662520729685

# %% [markdown]
# Most of the price range between  40−
#  60 and the average product price is $45.22

# %% [markdown]
# ### Question 2 :\ which product generae the the highest profit for  Adidas (compare to the number of the unit sold) ?
# total sales of each product

# %%
P_TotalSales=df.groupby(['Product'])['Total Sales'].sum().sort_values(ascending=False).to_frame()

# %%
P_TotalSales.plot.bar(figsize=(10, 5))

# Create a bar plot
sns.barplot(x=P_TotalSales.index, y=P_TotalSales['Total Sales'].values, data=R_TotalSales)

# Customize the plot
sns.set_style('darkgrid')
sns.set_palette('bright')

# Add a title and labels
plt.title('Total Sales By Product ')
plt.xlabel('Products')
plt.ylabel('Total Sales in Millions')

# Customize the appearance of the bars
plt.bar_width = 0.4
plt.bar_edgecolor='white'


# Show the plot
plt.show()

# %%
P_TotalSales
# Out:
#                            Total Sales
# Product
# Men's Street Footwear      208826244.0
# Women's Apparel            179038860.0
# Men's Athletic Footwear    153673680.0
# Women's Street Footwear    128002813.0
# Men's Apparel              123728632.0
# Women's Athletic Footwear  106631896.0

# %% [markdown]
# ## Most profatible product

# %%
df.head()
# Out:
# 3     Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
# 3                    Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
# 3  Operating Profit  Operating Margin Sales Method  Year  Month  Day
# ...

# %%
# define Seaborn color palette to use
palette_color = sns.color_palette('bright')
  
# plotting data on chart
plt.pie(P_TotalSales['Total Sales'], labels=P_TotalSales.index, colors=palette_color, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %% [markdown]
# As it shows in the chart the products the generate the most total sales are men's street footwear

# %% [markdown]
# ### Question 3:\ what is the common sales method that the users use to purchase Adidas (and the profit of each method) ?

# %%
df['Sales Method'].unique()
# Out:
# array(['In-store', 'Outlet', 'Online'], dtype=object)

# %% [markdown]
# adidas sell its products through three ways In-sotre , Outlet , Online .

# %%
df.head()
# Out:
# 3     Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
# 3                    Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
# 3  Operating Profit  Operating Margin Sales Method  Year  Month  Day
# ...

# %%
Method_TotalSales=df.groupby(['Sales Method'])['Total Sales'].sum().sort_values(ascending=False).to_frame()

# %%
# Create a bar plot
sns.barplot(x=Method_TotalSales.index, y=Method_TotalSales['Total Sales'].values, data=Method_TotalSales)

# Customize the plot
sns.set_style('darkgrid')
sns.set_palette('bright')

# Add a title and labels
plt.title('Total Sales By Sales Method ')
plt.xlabel('Sales Method')
plt.ylabel('Total Sales in Millions')

# Customize the appearance of the bars
plt.bar_width = 0.4
plt.bar_edgecolor='white'


# Show the plot
plt.show()

# %% [markdown]
# It's clear that retailers sell more products in-store

# %% [markdown]
# Adidas Mostly generate hihger sales through in-store , higher thant outlet by almost half a million
# Online coming in last as the least profatile gate of adidas by almost 1 million from the leading ميته مليون ترا مو واحد مليون

# %% [markdown]
# ### Question 4 :\ the relationship between the price per unit and the units sold ? dose the lower price means that units sold are higher ?

# %%
df.head()
# Out:
# 3     Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
# 3                    Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
# 3  Operating Profit  Operating Margin Sales Method  Year  Month  Day
# ...

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a20fa_row0_col0, #T_a20fa_row1_col1, #T_a20fa_row2_col2, #T_a20fa_row3_col3, #T_a20fa_row4_col4, #T_a20fa_row5_col5, #T_a20fa_row6_col6, #T_a20fa_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a20fa_row0_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a20fa_row0_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_a20fa_row0_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a20fa_row0_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a20fa_row0_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a20fa_row0_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a20fa_row0_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a20fa_row1_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_a20fa_row1_col2, #T_a20fa_row2_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_a20fa_row1_col3 {
# ...

# %%
# Create a scatter plot
sns.scatterplot(x='Price per Unit', y='Units Sold', data=df)

# Show the plot
plt.show()

# %% [markdown]
# As shown in the scatter chart above there is no relationship between the price and the number of units sold , as the lower the product in price dose not nessassery mean the number of units sold will be higher

# %% [markdown]
# ### َQuestion :/ wihch region generate higher profit (percentage of sales in eah region)?

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method', 'Year', 'Month',
#        'Day'],
#       dtype='object', name=3)

# %%
Region=df.groupby(['Region'])['Operating Profit'].sum().sort_values(ascending=True).to_frame()

plt.barh( Region.index,Region['Operating Profit'])
 
# setting label of y-axis
plt.ylabel("Region")
 
# setting label of x-axis
plt.xlabel("Profit")
plt.title("Profit By Region")
plt.show()

# %% [markdown]
# the highest profatable region is West

# %% [markdown]
# # profit distribution over time(month) ?  line chart

# %%
df.head()
# Out:
# 3     Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
# 3                    Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
# 3  Operating Profit  Operating Margin Sales Method  Year  Month  Day
# ...

# %%
sales_by_month = df.groupby(['Year','Month'])['Total Sales'].sum().reset_index()


# Set a new color palette for hue

palette=sns.color_palette('dark:#5A9',as_cmap=True)

# Plot line chart
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
sns.lineplot(data=sales_by_month, x='Month', y='Total Sales',hue='Year',marker='o',palette=palette)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total Sales'>

# %% [markdown]
# As shown in the graph there was decline in the profit in 2020-6 and in 2020-11 this is mybe becouse of corona since major sales happend in the in-store , and at that time the store were closed , after that the profit start to increase over time with minor decline

# %% [markdown]
# ### Question : which city that generate hgihest  average profit ?

# %%
# city_profit=df[['City','Operating Profit']]
city_profit=df.groupby('City')['Operating Profit'].sum().sort_values(ascending=False).to_frame()
city_profit
# Out:
#                 Operating Profit
# City
# Charleston           15607190.11
# New York             13899973.16
# Miami                12168619.11
# Portland             10760799.37
# San Francisco        10256249.56
# Houston               9845141.06
# Charlotte             9756422.87
# Albany                9429850.91
# New Orleans           9417233.49
# Birmingham            9147581.39
# Los Angeles           9044920.84
# Dallas                8843063.29
# Orlando               8757587.81
# Knoxville             8493660.06
# Detroit               8135894.02
# Boise                 8121115.10
# Richmond              7719430.68
# Denver                7713555.83
# Columbus              7528840.09
# Las Vegas             7060651.92
# Seattle               6991403.13
# Atlanta               6893289.61
# Albuquerque           6738060.41
# Cheyenne              6544071.15
# Jackson               6369094.73
# Billings              6232037.55
# Honolulu              5849794.07
# ...

# %%
city_profit.plot.bar(figsize=(15, 10))
#city_profit.plot(kind='bar')
plt.xlabel('Fruits')
plt.ylabel('Values')
plt.title('Bar Plot with Values')
# plt.yticks([x for x in range(0,20000000,5000000)])
plt.show()

# %% [markdown]
# ### Question :  total sales for each product in each region  ?

# %%
# creating pivot table

pivot_table =df.pivot_table(index='Region', columns='Product', values='Operating Profit')
# pivot_table.plot(kind='bar')
# plt.show()
pivot_table

# Profit_regions_Cities=df[['Region','City','Operating Profit']]

# # Create a pivot table
# pivot_table = Profit_regions_Cities.pivot_table(values='Operating Profit', index='Region', columns='City', aggfunc=sum)

# # Print the pivot table
# pivot_table=pivot_table.fillna(0)

# pivot_table
# Out:
# Product    Men's Apparel  Men's Athletic Footwear  Men's Street Footwear  \
# Region
# Midwest     23181.183718             23739.789840           48068.502276
# Northeast   20609.955379             25885.529394           53930.093990
# South       25159.724965             34693.061562           39957.849514
# Southeast   40608.255882             46648.365392           71680.597990
# West        34085.895788             35808.624024           49555.775707
#
# Product    Women's Apparel  Women's Athletic Footwear  Women's Street Footwear
# Region
# Midwest       39503.455673               16166.263462             18607.941186
# Northeast     34088.941389               17161.945657             20092.694924
# South         50885.697118               29449.245937             32139.157257
# Southeast     68036.985049               33933.938382             35932.135245
# West          35029.524216               28896.241379             36145.120319

# %%
pivot_table.plot(kind='bar')
plt.show()

# %%
df.to_csv(r"C:\Users\Lenovo\Documents\AdidasSalesCleaned.csv")
